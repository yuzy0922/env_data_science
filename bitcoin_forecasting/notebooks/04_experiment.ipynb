# %% [markdown]
# # Reporting summary:
# - Iterate rolling window cross validation experiments by changing:
#  - Forecasting models [Logistic, LGBMC, RFC, FNN]
#  - Dataset to be inputted [Blockchain information only, Blockchain and Macroeconomic information, All of Blockchain, Altcoin, and Macroeconomic information]
#  - The number of days ahead to be forecasted [End of Day, 2 days ahead, 3 days ahead]
#
# - In each iterated experiment:
#  - Dependent variable: Binary log return of Bitcoin price (Up / Down)
#  - Independent variables: The latest and available information of Blockchain metrics, Altcoin market, and Macroeconomic market
#  - Date: 480 days for train, 60 days for validation, and 60 days for test
#  - Procedures: standardization of independent variables, feature selections with Boruta, optimization of hyperparameters with Optuna using train and validation data, re-learning and forecasting using train_validation and test data, Calculate evaluation metrics such as F1 and accuracy scores

# %% [markdown]
# # Import the libraries and data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import warnings
warnings.simplefilter('ignore')

path = "..\data"

# Import the user-defined modules
import sys
sys.path.append(path+'\..\src')
import rwcv
from rwcv import rwcv

# %% [markdown]
# # Experiment

# %% [markdown]
# ## Rolling Window Cross Validation

# %%
models = ["Logistic", "LGBMC", "RFC"]
dataset = ["Blockchain", "BlockchainMacro", "BlockchainAltcoinMacro"]
DV_shifts = [1,2,3]

for mdl in models:
    for ds in dataset:
        for dv in DV_shifts:
            output = rwcv(model=mdl, dataset=ds, DV_shifts=dv)
# Out:
# CV:  1
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	81
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	81
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	81
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	81
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	81
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	81
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	81
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	81
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	0
# Tentative: 	81
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	0
# Tentative: 	81
# Rejected: 	0
# Iteration: 	11 / 100
# Confirmed: 	3
# Tentative: 	2
# Rejected: 	76
# Iteration: 	12 / 100
# Confirmed: 	3
# Tentative: 	2
# Rejected: 	76
# Iteration: 	13 / 100
# Confirmed: 	3
# Tentative: 	2
# Rejected: 	76
# Iteration: 	14 / 100
# Confirmed: 	3
# Tentative: 	2
# Rejected: 	76
# ...
